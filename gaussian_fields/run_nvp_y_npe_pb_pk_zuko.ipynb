# %%
# %pip install zuko
# Out:
# Requirement already satisfied: zuko in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (1.1.0)
# Requirement already satisfied: numpy>=1.20.0 in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (from zuko) (1.26.4)
# Requirement already satisfied: torch>=1.12.0 in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (from zuko) (2.2.2)
# Requirement already satisfied: filelock in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (from torch>=1.12.0->zuko) (3.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (from torch>=1.12.0->zuko) (4.11.0)
# Requirement already satisfied: sympy in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (from torch>=1.12.0->zuko) (1.12)
# Requirement already satisfied: networkx in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (from torch>=1.12.0->zuko) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (from torch>=1.12.0->zuko) (3.1.3)
# Requirement already satisfied: fsspec in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (from torch>=1.12.0->zuko) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (from jinja2->torch>=1.12.0->zuko) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /Users/Jed.Homer/phd/teaching/sbi_ml_lab/.venv/lib/python3.9/site-packages (from sympy->torch>=1.12.0->zuko) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import torch
import torch.nn as nn
import torch.distributions as td
import numpy as np 
import matplotlib.pyplot as plt
from tqdm.notebook import trange 

import zuko

from flow.nvp_y import RealNVP

def convert(x):
    return torch.as_tensor(x).float()

# %%
field_type = "gaussian" 
data_dir = "data/"

AB = np.array([1., 1.])
lower = np.array([0.1, .1])
upper = np.array([2., 2.])
parameter_names = ["A", "B"]

# Load data 
D = np.load(data_dir + field_type + "_fields_Pk.npy")
Y = np.load(data_dir + field_type + "_fields_parameters.npy")
D0 = np.load(data_dir + field_type + "_fields_Pk_fiducial.npy")

ccovariance = np.load(data_dir + field_type + "_fields_Pk_covariance.npy") 

print(f"Data: {D.shape=} {Y.shape=}")

# Load compressed data
X = np.load(os.path.join(data_dir, field_type + "_nn_summaries_Pk.npy"))
# X_ = np.load(os.path.join(data_dir, field_type + "_nn_summary_data_Pk.npy"))
X_ = np.load(os.path.join(data_dir, field_type + "_nn_summary_mean.npy"))

def preprocess_fn(x, y):
    return (x - Y.mean(axis=0)), (y - X.mean(axis=0))

print(f"Summaries: {X.shape=} {Y.shape=}")
# Out:
# Data: D.shape=(50000, 29) Y.shape=(50000, 2)
# Summaries: X.shape=(50000, 2) Y.shape=(50000, 2)

# %%
# Data
data_dim = X.shape[-1] 
parameter_dim = Y.shape[-1]
# Model
H = 128 # Hidden size
L = 2 # Layers
K = 2
# Optimisation
lr = 1e-3
n_steps = 10_000
batch_size = 400

# %%
flow = zuko.flows.MAF(data_dim, parameter_dim, transforms=K, hidden_features=[H] * L)

# %%
def get_data(n):
    ix = np.random.randint(len(X), size=(n,))
    return convert(Y[ix]), convert(X[ix]) # NPE

optimizer = torch.optim.Adam(flow.parameters(), lr=lr, weight_decay=1e-5)

losses = []
with trange(n_steps) as steps:
    for s in steps:
        y, x = get_data(batch_size)

        loss = -flow(x).log_prob(y).mean()
        # loss = -flow.log_prob(x, y).mean()
        
        optimizer.zero_grad()
        loss.backward(retain_graph=True)
        optimizer.step()

        losses.append(loss.item())
        steps.set_postfix(loss=f"{loss:.3E}")
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]

# %%
plt.figure()
plt.plot(losses)
plt.show()

# %%
plt.figure(dpi=200)
print(X.shape, Y.shape)
z = flow(convert(X)).sample((10,)).reshape(-1, 2)
z = z.detach().numpy()
# print(z.shape)[0].detach().numpy()
# z = flow(Y).sample((1000,),)[0].detach().numpy()
plt.subplot(221)
plt.scatter(z[:, 0], z[:, 1], s=1.)
plt.title(r'$z = f(X)$')

prior = td.MultivariateNormal(torch.zeros(data_dim), torch.eye(data_dim))
z = prior.sample((len(X),))
plt.subplot(222)
plt.scatter(z[:, 0], z[:, 1], s=1.)
plt.title(r'$z \sim p(z)$')

plt.subplot(223)
plt.scatter(X[:, 0], X[:, 1], c='r', s=1.)
plt.title(r'$X \sim p(X)$')

plt.subplot(224)
# x = flow.sample(len(X), convert(Y)).detach().numpy() # Sample plot at parameters given
# x = flow(convert(X)).sample((1,)).detach().numpy() # Sample plot at parameters given
flow(convert(X))
# flow(convert(X)).inv()
print(x.shape)
plt.scatter(x[:, 0], x[:, 1], c='r', s=1.)
plt.title(r'$X = g(z)$')

plt.show()
# Out:
# (50000, 2) (50000, 2)
# torch.Size([400, 2])

# %%
n_posterior_samples = 40_000

# %%
from chainconsumer import ChainConsumer 

# posterior_samples = flow.sample(
#     n_posterior_samples, 
#     torch.tile(convert(X_), (n_posterior_samples, 1))
# )
posterior_samples = flow(convert(X_)).sample((n_posterior_samples,)).squeeze()
print(posterior_samples.shape)
posterior_samples = posterior_samples.detach().numpy()

c = ChainConsumer()
c.add_chain(posterior_samples, parameters=parameter_names)
# c.add_covariance(AB, Finv, parameters=parameter_names)
fig = c.plotter.plot(truth=AB)
# Out:
# torch.Size([40000, 2])

# %%
from powerbox import get_power 
from chainconsumer import ChainConsumer 

def get_F(AB, field):
    """
        Calculate the Fisher information of the field
        given the parameter values A, B = AB.
    """
    A, B = AB
    
    # Power spectrum and k-modes
    Pk, k = get_power(
        field, boxlength=1., ignore_zero_mode=True
    )
    
    # Inverse covariance (covariance is diagonal)
    Cinv = np.diag(1. / Pk) 

    # Covariance derivatives
    C_A = np.diag(k ** -B)
    C_B = np.diag(-Pk * np.log(k))

    # Fisher matrix elements for each parameter
    F_AA = 0.5 * np.trace((C_A @ Cinv @ C_A @ Cinv))
    F_AB = 0.5 * np.trace((C_A @ Cinv @ C_B @ Cinv))
    F_BA = 0.5 * np.trace((C_B @ Cinv @ C_A @ Cinv))
    F_BB = 0.5 * np.trace((C_B @ Cinv @ C_B @ Cinv))

    return np.array([[F_AA, F_AB], [F_BA, F_BB]])

F = get_F(AB, D0.mean(axis=0))
Finv = np.linalg.inv(F)

# posterior_samples = flow.sample(
#     n_posterior_samples, 
#     torch.tile(convert(X_), (n_posterior_samples, 1))
# )
# posterior_samples = posterior_samples.detach().numpy()

c = ChainConsumer()
c.add_chain(posterior_samples, parameters=parameter_names)
c.add_covariance(AB, Finv, parameters=parameter_names)
fig = c.plotter.plot(truth=AB)
plt.show()

# %%
def fisher(θ, k, N):
    A, B = θ
    _Pk = A * k ** -B 
    
    Cinv = np.diag(1. / _Pk)
    C_A = np.diag(k ** -B)
    C_B = np.diag(-_Pk * np.log(k))

    F_AA = 0.5 * np.trace((C_A @ Cinv @ C_A @ Cinv))
    F_AB = 0.5 * np.trace((C_A @ Cinv @ C_B @ Cinv))
    F_BA = 0.5 * np.trace((C_B @ Cinv @ C_A @ Cinv))
    F_BB = 0.5 * np.trace((C_B @ Cinv @ C_B @ Cinv))

    F = np.array(
        [
            [F_AA, F_AB], 
            [F_BA, F_BB]
        ]
    )
    return F

bins_field = np.array([
    6.74175608,  15.45734344,  24.48480767,  34.53463474,
    43.70699212,  53.82159711,  63.83737213,  73.50921216,
    83.52835261,  93.09965685, 103.15862259, 112.95713549,
    122.92965035, 132.46581717, 142.10107612, 151.73095604,
    161.58263501, 171.75896138, 181.28953473, 191.21116407,
    200.95365826, 210.71623074, 220.44628398, 230.19829726,
    239.89968893, 250.02951477, 259.70986696, 268.66110077,
    276.99921658
])

alpha = np.array([0.5, 0.5])
F = fisher(alpha, bins_field, D.shape[-1])
Finv = np.linalg.inv(F)

from chainconsumer import ChainConsumer

c = ChainConsumer()
c.add_chain(posterior_samples, parameters=parameter_names)
c.add_covariance(alpha, Finv)
c.plotter.plot(truth=alpha)
plt.show()

# %%
from mflow.made import MADE
from mflow.batch import BatchNormFlow
from fmlwperm import Perm
from flow import Flow

data_dim = 2
H = 32
context_dim = 2

flow = Flow(
    MADE(data_dim, H, context_dim, act="tanh"),
    BatchNormFlow(data_dim),
    Perm(data_dim),
    MADE(data_dim, H, context_dim, act="tanh"),
    BatchNormFlow(data_dim),
    Perm(data_dim),
    MADE(data_dim, H, context_dim, act="tanh"),
)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 from mflow.made import MADE
#       2 from mflow.batch import BatchNormFlow
#       3 from fmlwperm import Perm
#
# ModuleNotFoundError: No module named 'mflow'
